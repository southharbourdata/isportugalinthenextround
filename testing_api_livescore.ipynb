# %%
import requests
from bs4 import BeautifulSoup

# %%
result = requests.get("https://www.bbc.com/sport/football/european-championship/scores-fixtures/2021-06-23")
src = result.content
soup = BeautifulSoup(src, 'html.parser')

# %%
<span role="region" aria-live="polite" data-reactid=".280oo4vdajq.2.0.0.2"><div data-reactid=".280oo4vdajq.2.0.0.2.0"><div class="qa-match-block" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June"><h3 class="gel-minion sp-c-match-list-heading" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.0">European Championship</h3><h4 class="gel-minion gs-u-align-center gs-u-mt" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.1">Group E</h4><ul class="gs-o-list-ui gs-o-list-ui--top-no-border gs-o-list-ui--bottom-no-border" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2"><li class="gs-o-list-ui__item gs-u-pb-" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper"><a class="sp-c-fixture__block-link" href="/sport/football/51198460" data-istats-container="match_link" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0"><article class="sp-c-fixture" data-event-id="EFBO2041913" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0"><div class="sp-c-fixture__wrapper" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0"><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-home" data-team-id="TFBB507" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.0"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.0.0"><abbr title="Slovakia" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.0.0.0">Slovakia</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.0.0.1">Slovakia</span></span></span><span class="sp-c-fixture__block sp-c-fixture__block--time gel-brevier" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.1"><span class="sp-c-fixture__number sp-c-fixture__number--time" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.1.0">17:00</span></span><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-away" data-team-id="TFBB118" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.2"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.2.0"><abbr title="Spain" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.2.0.0">Spain</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.0.2.0.1">Spain</span></span></span></div><aside class="sp-c-fixture__aside sp-c-fixture-player-actions__aside" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.2"><span class="sp-c-fixture__status-wrapper qa-sp-fixture-status" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.2.0"><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.2.0.0"></span><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.2.0.1"></span></span></aside><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041913-wrapper.0.0.3"></span></article></a></li><li class="gs-o-list-ui__item gs-u-pb-" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper"><a class="sp-c-fixture__block-link" href="/sport/football/51198453" data-istats-container="match_link" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0"><article class="sp-c-fixture" data-event-id="EFBO2041914" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0"><div class="sp-c-fixture__wrapper" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0"><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-home" data-team-id="TFBB361" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.0"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.0.0"><abbr title="Sweden" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.0.0.0">Sweden</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.0.0.1">Sweden</span></span></span><span class="sp-c-fixture__block sp-c-fixture__block--time gel-brevier" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.1"><span class="sp-c-fixture__number sp-c-fixture__number--time" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.1.0">17:00</span></span><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-away" data-team-id="TFBB511" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.2"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.2.0"><abbr title="Poland" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.2.0.0">Poland</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.0.2.0.1">Poland</span></span></span></div><aside class="sp-c-fixture__aside sp-c-fixture-player-actions__aside" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.2"><span class="sp-c-fixture__status-wrapper qa-sp-fixture-status" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.2.0"><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.2.0.0"></span><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.2.0.1"></span></span></aside><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.2.$EFBO2041914-wrapper.0.0.3"></span></article></a></li></ul><div data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June"><h4 class="gel-minion gs-u-align-center gs-u-mt" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.0">Group F</h4><ul class="gs-o-list-ui gs-o-list-ui--top-no-border gs-o-list-ui--bottom-no-border" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1"><li class="gs-o-list-ui__item gs-u-pb-" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper"><a class="sp-c-fixture__block-link" href="/sport/football/51198467" data-istats-container="match_link" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0"><article class="sp-c-fixture" data-event-id="EFBO2041916" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0"><div class="sp-c-fixture__wrapper" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0"><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-home" data-team-id="TFBB357" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.0"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.0.0"><abbr title="Germany" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.0.0.0">Germany</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.0.0.1">Germany</span></span></span><span class="sp-c-fixture__block sp-c-fixture__block--time gel-brevier" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.1"><span class="sp-c-fixture__number sp-c-fixture__number--time" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.1.0">20:00</span></span><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-away" data-team-id="TFBB538" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.2"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.2.0"><abbr title="Hungary" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.2.0.0">Hungary</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.0.2.0.1">Hungary</span></span></span></div><aside class="sp-c-fixture__aside sp-c-fixture-player-actions__aside" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.2"><span class="sp-c-fixture__status-wrapper qa-sp-fixture-status" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.2.0"><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.2.0.0"></span><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.2.0.1"></span></span></aside><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041916-wrapper.0.0.3"></span></article></a></li><li class="gs-o-list-ui__item gs-u-pb-" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper"><a class="sp-c-fixture__block-link" href="/sport/football/51198474" data-istats-container="match_link" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0"><article class="sp-c-fixture" data-event-id="EFBO2041915" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0"><div class="sp-c-fixture__wrapper" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0"><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-home" data-team-id="TFBB359" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.0"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.0.0"><abbr title="Portugal" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.0.0.0">Portugal</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.0.0.1">Portugal</span></span></span><span class="sp-c-fixture__block sp-c-fixture__block--time gel-brevier" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.1"><span class="sp-c-fixture__number sp-c-fixture__number--time" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.1.0">20:00</span></span><span class="sp-c-fixture__team sp-c-fixture__team--time sp-c-fixture__team--time-away" data-team-id="TFBB368" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.2"><span class="sp-c-fixture__team-name-wrap" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.2.0"><abbr title="France" class="gs-u-display-block gs-u-display-none@m sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.2.0.0">France</abbr><span class="gs-u-display-none gs-u-display-block@m qa-full-team-name sp-c-fixture__team-name-trunc" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.0.2.0.1">France</span></span></span></div><aside class="sp-c-fixture__aside sp-c-fixture-player-actions__aside" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.2"><span class="sp-c-fixture__status-wrapper qa-sp-fixture-status" data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.2.0"><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.2.0.0"></span><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.2.0.1"></span></span></aside><span data-reactid=".280oo4vdajq.2.0.0.2.0.$0European ChampionshipWednesday-23rd-June.3:$10European ChampionshipWednesday-23rd-June.1.$EFBO2041915-wrapper.0.0.3"></span></article></a></li></ul></div></div></div></span>

# %%
table = soup.find_all("span")
table
# Out:
# [<span id="idcta-username">BBC Account</span>,
#  <span class="hidden-span">Notifications</span>,
#  <span id="not-num"></span>,
#  <span class="orb-icon orb-icon-arrow"></span>,
#  <span class="gs-u-vh">BBC</span>,
#  <span class="gel-icon"><svg height="32" viewbox="0 0 32 32" width="32"><path d="M0 4h32v6H0V4zm0 10h32v6H0v-6zm0 10h32v6H0v-6z"></path></svg></span>,
#  <span class="sp-c-sport-navigation__item sp-c-sport-navigation__item--all" id="sp-nav-all-item" role="presentation"><button class="qa-all-sport-button sp-c-sport-navigation__link" id="sp-nav-all-sport-button" role="menuitem" type="button"><span class="gel-icon"><svg height="32" viewbox="0 0 32 32" width="32"><path d="M0 4h32v6H0V4zm0 10h32v6H0v-6zm0 10h32v6H0v-6z"></path></svg></span> All Sport</button></span>,
#  <span class="gel-icon"><svg height="32" viewbox="0 0 32 32" width="32"><path d="M0 4h32v6H0V4zm0 10h32v6H0v-6zm0 10h32v6H0v-6z"></path></svg></span>,
# ...

# %%
table = soup.find_all("li")
results_table = table[-3]
lists_matches = results_table.find_all("a")
test_li = lists_matches[1]
lists_test = test_li.find_all("span")

# %%
for l in lists_matches:
    content = l.find_all("span")
    first_team = (content[1].find_all("abbr")[0].text, content[5].text)
    second_team = (content[7].find_all("abbr")[0].text, content[12].text)
    print("{first_team} is playing against {second_team}, and the score is: {score_1} - {score_2}".format(
        first_team=first_team[0], second_team=second_team[0],score_1=first_team[1],score_2=second_team[1]))
    print(first_team)
    print(second_team)
# Out:
# Croatia is playing against Scotland, and the score is: 3 - 1
# ('Croatia', '3')
# ('Scotland', '1')
# Czech Rep is playing against England, and the score is: 0 - 1
# ('Czech Rep', '0')
# ('England', '1')

# %%
import os
import parse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-4df507600872> in <module>
#       1 import os
# ----> 2 import parse
#
# ModuleNotFoundError: No module named 'parse'

# %%
search_words = ["Luffy", "Zoro", "Nami", "Sanji", "Chopper"]
img_dir = "./image_folder/"
for word in search_words:
    dir_path = img_dir + word
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
urlKeyword = parse.quote(word)
#Create url with target word
url = "https://www.google.com/search?hl=jp&q=' + urlKeyword + ‘&btnG=Google+Search&tbs=0&safe=off&tbm=isch"
# headers is necessary when you send request
headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:47.0) Gecko/20100101 Firefox/47.0",}
#Request is made with url and headers
request = req.Request(url=url, headers=headers)
page = req.urlopen(request)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-8c00c1a2e4be> in <module>
#       5 if not os.path.exists(dir_path):
#       6     os.makedirs(dir_path)
# ----> 7 urlKeyword = parse.quote(word)
#       8 #Create url with target word
#       9 url = "https://www.google.com/search?hl=jp&q=' + urlKeyword + ‘&btnG=Google+Search&tbs=0&safe=off&tbm=isch"
#
# NameError: name 'parse' is not defined

# %%
html = page.read().decode(‘utf-8’)
#Use BeutifulSoup, "html.parser". HTML object is available in Python.
html = bs4.BeautifulSoup(html, "html.parser")
#rg_meta.notranslate is for extracting data without permission(not sure)
elems = html.select(‘.rg_meta.notranslate’)
counter = 0
error_counter = 0
for ele in elems:
ele = ele.contents[0].replace(‘"‘,’’).split(‘,’)
eledict = dict()
#imageURL is indicated here.
for e in ele:
num = e.find(‘:’)
eledict[e[0:num]] = e[num+1:]
imageURL = eledict[‘ou’]
#URL retrieve: extract imageURL from file_path
#Try catching image, if error occurs, execute except program
try:
file_path = dir_path + "/" + str(counter)+".jpg"
urlretrieve(imageURL, file_path)
counter += 1
except Exception as e:
error_counter += 1
if counter == 1:
print("Start downloading", word)
if counter==200:
break
print("{} errors occur out of ".format(counter, error_counter))
